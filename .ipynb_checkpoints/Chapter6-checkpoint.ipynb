# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00359/NewsAggregatorDataset.zip
# Out:
# Will not apply HSTS. The HSTS database must be a regular and non-world-writable file.
# ERROR: could not open HSTS store at '/home/namiki/.wget-hsts'. HSTS will be disabled.
# --2020-04-13 23:49:15--  https://archive.ics.uci.edu/ml/machine-learning-databases/00359/NewsAggregatorDataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29224203 (28M) [application/x-httpd-php]
# Saving to: ‘NewsAggregatorDataset.zip’
#
# NewsAggregatorDatas 100%[===================>]  27.87M  63.7KB/s    in 10m 2s
#
# 2020-04-13 23:59:18 (47.4 KB/s) - ‘NewsAggregatorDataset.zip’ saved [29224203/29224203]

# %%
# !unzip NewsAggregatorDataset.zip
# Out:
# Archive:  NewsAggregatorDataset.zip
#   inflating: 2pageSessions.csv
#    creating: __MACOSX/
#   inflating: __MACOSX/._2pageSessions.csv
#   inflating: newsCorpora.csv
#   inflating: __MACOSX/._newsCorpora.csv
#   inflating: readme.txt
#   inflating: __MACOSX/._readme.txt

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
names = [
"ID",
"TITLE",
"URL",
"PUBLISHER",
"CATEGORY",	
"STORY",
"HOSTNAME",
"TIMESTAMP",
]

# %%
News category (b = business, t = science and technology, e = entertainment, m = health)

# %%
df = pd.read_csv("./newsCorpora/newsCorpora.csv",
                 delimiter="\t",
                 names=names)

# %%
df.head()
# Out:
#    ID                                              TITLE  \
# 0   1  Fed official says weak data caused by weather,...
# 1   2  Fed's Charles Plosser sees high bar for change...
# 2   3  US open: Stocks fall after Fed official hints ...
# 3   4  Fed risks falling 'behind the curve', Charles ...
# 4   5  Fed's Plosser: Nasty Weather Has Curbed Job Gr...
#
#                                                  URL          PUBLISHER  \
# 0  http://www.latimes.com/business/money/la-fi-mo...  Los Angeles Times
# 1  http://www.livemint.com/Politics/H2EvwJSK2VE6O...           Livemint
# 2  http://www.ifamagazine.com/news/us-open-stocks...       IFA Magazine
# 3  http://www.ifamagazine.com/news/fed-risks-fall...       IFA Magazine
# 4  http://www.moneynews.com/Economy/federal-reser...          Moneynews
#
#   CATEGORY                          STORY             HOSTNAME      TIMESTAMP
# 0        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM      www.latimes.com  1394470370698
# ...

# %%
credible = ["Reuters", "Huffington Post", "Businessweek", "Contactmusic.com", "Daily Mail"]

# %%
extracted_df = df[df.PUBLISHER.isin(credible)]
extracted_df = extracted_df.sample(frac=1,random_state=1984)

# %%
train, validate, test = np.split(extracted_df, [int(.6*len(extracted_df)), int(.8*len(extracted_df))])

# %%
train
# Out:
#             ID                                              TITLE  \
# 114426  114762  Taylor Swift Crashes Super Fan's Bridal Shower...
# 184786  185122  OEDC backs Osbourne as 100000 jobs are being c...
# 4934      4935  BoE's Carney says worried UK mortgage underwri...
# 375831  376291  Elizabeth Hasselbeck Expresses Anger At Rosie ...
# 2917      2918  Zac Efron - Zac Efron 'thinking about' High Sc...
# 312633  313093                   Katie Couric - Katie Couric weds
# 223520  223966  Credit Suisse guilty plea likely to be announc...
# 224847  225293  Republicans cook up get-out clause Michelle Ob...
# 122847  123183  AC/DC guitarist Malcolm Young 'too sick to pla...
# 360657  361117  Khloé Kardashian - Khloé Kardashian has 'learn...
# 130877  131213       Miley Cyrus could be in hospital for 27 days
# 356634  357094  FOREX-Dollar rallies on strong US jobs data; e...
# 53315    53316  Gwyneth Paltrow and Chris Martin clashed over ...
# ...
